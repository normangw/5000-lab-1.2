# %% [markdown]
# ---
# title: "Professional Slide Deck"
# author: "Your Name"
# format: revealjs
# bibliography: ../../reference.bib
# ---
#
# # Introduction
#
# Welcome to my slide deck!
#
# This deck is built with **Quarto** and **Reveal.js**.
#
# ## Research Background
#
# Some important research findings include:
#
# - The monopoly of violence in Colombia [@acemoglu2013monopoly]
# - Historical states and development in Vietnam [@dell2018historical]
#
# Here are two images:
#
# ![Image 1](../images/headshot.jpg){width=300px}
# ![Image 2](../images/old_headshot.jpg){width=300px}
#
# ## Plot Slide
#
# ```{python}
# #| code-fold: true
# #| echo: false
# #| fig-width: 6
# #| fig-height: 4
#
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.linspace(0, 2*np.pi, 100)
# y = np.sin(x)
#
# # Plot
# plt.figure(figsize=(6,4))
# plt.plot(x, y, label="sin(x)", color="blue")
# plt.title("Sample Plot")
# plt.xlabel("x")
# plt.ylabel("sin(x)")
# plt.legend()
# plt.show()
# ```
#
# ## Quarto
#
# Quarto enables you to weave together content and executable code into a finished document. To learn more about Quarto see <https://quarto.org>.
